# %% [markdown]
# ## Import

# %%
import numpy as np
import pandas as pd
import scanpy as sc
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

sc.settings.verbosity = 3
sc.settings.set_figure_params(dpi=80)
# %matplotlib inline

# %%
import os 
os.chdir('/Users/gracenbourbeau/Downloads/luad_tcga_pan_can_atlas_2018/')
# %pwd
# Out:
# '/Users/gracenbourbeau/Downloads/luad_tcga_pan_can_atlas_2018'

# %%
raw_rna_data = pd.read_table("data_mrna_seq_v2_rsem.txt", sep="\t")
raw_rna_data.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id  TCGA-05-4244-01  TCGA-05-4249-01  \
# 0         NaN       100130426           0.0000           0.0000
# 1         NaN       100133144          10.0113           7.1957
# 2    UBE2Q2P2       100134869          11.2820          12.4436
# 3     HMGB1P1           10357          49.5994          90.5117
# 4         NaN           10431         848.9400         924.0160
#
#    TCGA-05-4250-01  TCGA-05-4382-01  TCGA-05-4384-01  TCGA-05-4389-01  \
# 0           0.0000           0.0000           0.0000           0.0000
# 1           7.2453          11.3311           3.2254           4.0000
# 2           6.0184           7.5740           3.4942          13.7852
# 3          49.5366          82.8303          72.5351          66.3658
# 4        1140.6800         807.1730         562.0040        1342.6200
#
#    TCGA-05-4390-01  TCGA-05-4395-01  ...  TCGA-NJ-A4YG-01  TCGA-NJ-A4YI-01  \
# 0           0.0000           0.0000  ...           0.0000           0.0000
# 1           7.1084           3.4360  ...          11.7148           3.6657
# 2           7.5810          12.1335  ...          11.9573           9.7617
# 3         109.1810          57.0596  ...         163.5740         130.7490
# 4        1148.3300         955.9140  ...         919.1690         403.4910
#
#    TCGA-NJ-A4YP-01  TCGA-NJ-A4YQ-01  TCGA-NJ-A55A-01  TCGA-NJ-A55O-01  \
# 0           0.0000           0.0000           0.0000           0.0000
# 1           2.3298          16.3214          20.3514          15.5193
# 2           8.3410           7.5330          17.2393          22.9872
# 3         101.7400          82.4231         100.4200         100.1870
# 4         918.9530         995.6060         536.7600         873.9790
#
#    TCGA-NJ-A55R-01  TCGA-NJ-A7XG-01  TCGA-O1-A52J-01  TCGA-S2-AA1A-01
# 0           0.0000           0.0000           0.0000           0.0000
# 1           8.4195          42.9857          14.0861          20.5338
# 2          10.3226          81.1128          24.1914           8.9500
# 3          74.7210          85.3715          61.1388          76.9265
# 4         766.7450         677.7330        1137.3200         565.4330
#
# [5 rows x 512 columns]

# %% [markdown]
# ## Count of genes & sample in mRNA Sequence Data

# %%
rna_clean = raw_rna_data.set_index("Entrez_Gene_Id").drop("Hugo_Symbol",axis=1).transpose()
print(f"There are {len(rna_clean)} samples in total & there are {len(rna_clean.columns)} genes in total.")
rna_clean.head()
# Out:
# There are 510 samples in total & there are 20531 genes in total.
# Entrez_Gene_Id   100130426  100133144  100134869  10357      10431      \
# TCGA-05-4244-01        0.0    10.0113    11.2820    49.5994    848.940
# TCGA-05-4249-01        0.0     7.1957    12.4436    90.5117    924.016
# TCGA-05-4250-01        0.0     7.2453     6.0184    49.5366   1140.680
# TCGA-05-4382-01        0.0    11.3311     7.5740    82.8303    807.173
# TCGA-05-4384-01        0.0     3.2254     3.4942    72.5351    562.004
#
# Entrez_Gene_Id   136542     155060     26823      280660     317712     ...  \
# TCGA-05-4244-01        0.0   345.2310     1.0472     0.0000        0.0  ...
# TCGA-05-4249-01        0.0   145.2020     1.6098     0.0000        0.0  ...
# TCGA-05-4250-01        0.0    51.7284     0.0000     0.0000        0.0  ...
# TCGA-05-4382-01        0.0   240.0220     0.4786     0.2393        0.0  ...
# TCGA-05-4384-01        0.0   274.2820     0.6109     0.0000        0.0  ...
#
# Entrez_Gene_Id   55055      11130      7789       158586     79364      \
# TCGA-05-4244-01    221.164    517.672    39.7940    292.521    959.246
# TCGA-05-4249-01    198.589    287.507    62.1376    493.560   1179.330
# TCGA-05-4250-01    520.899   1046.840    60.0182    365.415    843.903
# TCGA-05-4382-01    429.630    753.090    40.4424    346.752    946.687
# TCGA-05-4384-01    258.302    153.940    80.0244    563.225   1320.710
#
# Entrez_Gene_Id   440590     79699      7791       23140      26009
# TCGA-05-4244-01     0.6981   1088.050    2837.94     871.28    575.268
# TCGA-05-4249-01    20.2833    787.506    2351.25    1138.12    690.275
# TCGA-05-4250-01    26.5274    475.172    5437.45    1170.52    532.869
# TCGA-05-4382-01    64.8514    908.159    6770.15    1169.24    663.830
# TCGA-05-4384-01     7.9414    778.864    3341.48    1737.32    723.274
#
# [5 rows x 20531 columns]

# %% [markdown]
# ## Cleaning df from duplicative values, NA values

# %%
rna_clean.isnull().values.any() #any NA vals?

# columns with all the same value
unique_counts = rna_clean.nunique()
same_value_cols = unique_counts[unique_counts == 1].index.tolist()
print(f"There are {len(same_value_cols)} columns with the same value.")
print(f"{same_value_cols[0:10]}...")
# Out:
# There are 340 columns with the same value.
# [317712, 404770, 728045, 100131137, 143501, 9085, 253175, 286828, 653282, 267012]...

# %%
#need to drop the 340 columns with same vals
df_clean = rna_clean.drop(same_value_cols, axis = 1)
df_clean.head()
# Out:
# Entrez_Gene_Id   100130426  100133144  100134869  10357      10431      \
# TCGA-05-4244-01        0.0    10.0113    11.2820    49.5994    848.940
# TCGA-05-4249-01        0.0     7.1957    12.4436    90.5117    924.016
# TCGA-05-4250-01        0.0     7.2453     6.0184    49.5366   1140.680
# TCGA-05-4382-01        0.0    11.3311     7.5740    82.8303    807.173
# TCGA-05-4384-01        0.0     3.2254     3.4942    72.5351    562.004
#
# Entrez_Gene_Id   136542     155060     26823      280660     340602     ...  \
# TCGA-05-4244-01        0.0   345.2310     1.0472     0.0000     0.0000  ...
# TCGA-05-4249-01        0.0   145.2020     1.6098     0.0000     0.0000  ...
# TCGA-05-4250-01        0.0    51.7284     0.0000     0.0000     0.0000  ...
# TCGA-05-4382-01        0.0   240.0220     0.4786     0.2393     7.6577  ...
# TCGA-05-4384-01        0.0   274.2820     0.6109     0.0000     0.0000  ...
#
# Entrez_Gene_Id   55055      11130      7789       158586     79364      \
# TCGA-05-4244-01    221.164    517.672    39.7940    292.521    959.246
# TCGA-05-4249-01    198.589    287.507    62.1376    493.560   1179.330
# TCGA-05-4250-01    520.899   1046.840    60.0182    365.415    843.903
# TCGA-05-4382-01    429.630    753.090    40.4424    346.752    946.687
# TCGA-05-4384-01    258.302    153.940    80.0244    563.225   1320.710
#
# Entrez_Gene_Id   440590     79699      7791       23140      26009
# TCGA-05-4244-01     0.6981   1088.050    2837.94     871.28    575.268
# TCGA-05-4249-01    20.2833    787.506    2351.25    1138.12    690.275
# TCGA-05-4250-01    26.5274    475.172    5437.45    1170.52    532.869
# TCGA-05-4382-01    64.8514    908.159    6770.15    1169.24    663.830
# TCGA-05-4384-01     7.9414    778.864    3341.48    1737.32    723.274
#
# [5 rows x 20191 columns]

# %% [markdown]
# ## Clustering mRNA data

# %%
import umap
import seaborn as sns

# %%
df_clean.index
# Out:
# Index(['TCGA-05-4244-01', 'TCGA-05-4249-01', 'TCGA-05-4250-01',
#        'TCGA-05-4382-01', 'TCGA-05-4384-01', 'TCGA-05-4389-01',
#        'TCGA-05-4390-01', 'TCGA-05-4395-01', 'TCGA-05-4396-01',
#        'TCGA-05-4397-01',
#        ...
#        'TCGA-NJ-A4YG-01', 'TCGA-NJ-A4YI-01', 'TCGA-NJ-A4YP-01',
#        'TCGA-NJ-A4YQ-01', 'TCGA-NJ-A55A-01', 'TCGA-NJ-A55O-01',
#        'TCGA-NJ-A55R-01', 'TCGA-NJ-A7XG-01', 'TCGA-O1-A52J-01',
#        'TCGA-S2-AA1A-01'],
#       dtype='object', length=510)

# %%
data_gene = sc.AnnData(df_clean)

# %%
data_gene.var_names
# Out:
# Index(['100130426', '100133144', '100134869', '10357', '10431', '136542',
#        '155060', '26823', '280660', '340602',
#        ...
#        '55055', '11130', '7789', '158586', '79364', '440590', '79699', '7791',
#        '23140', '26009'],
#       dtype='object', name='Entrez_Gene_Id', length=20191)

# %%
data_gene.obs.columns
# Out:
# Index([], dtype='object')

# %%
sc.pl.highest_expr_genes(data_gene, n_top=20, )
#Show those genes that yield the highest fraction of counts in each single cell, across all cells.
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %% [markdown]
# ### Summary of highest count genes (n=5) (source: www.ncbi.nlm.nih.gov/gene/)

# %% [markdown]
# #### 8755: Predicted to be located in external side of plasma membrane and sperm head plasma membrane. Predicted to be part of protein-containing complex. ** interesting as this is associated with testicular issues

# %% [markdown]
# ## Clustering

# %%
sc.tl.pca(data_gene, n_comps=50)
sc.pp.neighbors(data_gene)
sc.tl.umap(data_gene)
sc.tl.leiden(data_gene)
sc.pl.umap(data_gene, color='leiden')
# Out:
# computing PCA
#     with n_comps=50
#     finished (0:00:00)
# computing neighbors
#     using 'X_pca' with n_pcs = 50
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:02)
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)
# running Leiden clustering
#     finished: found 9 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
pd.DataFrame(data_gene.obs['leiden'])
# Out:
#                 leiden
# TCGA-05-4244-01      2
# TCGA-05-4249-01      0
# TCGA-05-4250-01      0
# TCGA-05-4382-01      1
# TCGA-05-4384-01      2
# ...                ...
# TCGA-NJ-A55O-01      3
# TCGA-NJ-A55R-01      2
# TCGA-NJ-A7XG-01      3
# TCGA-O1-A52J-01      5
# TCGA-S2-AA1A-01      8
#
# [510 rows x 1 columns]

# %%
print("Explained variance of PCA:" , data_gene.uns['pca']['variance_ratio'].sum())
# Out:
# Explained variance of PCA: 0.9262285

# %%
clusters_df = pd.DataFrame(data_gene.obs['leiden']).reset_index(level=0)
clusters_df['index'] = clusters_df['index'].str[:-3]

# %%
df_PC = pd.DataFrame(data_gene.obsm['X_pca'])
df_PC['index'] = clusters_df['index']
df_PC  = df_PC.add_prefix('PC_')
df_PC.head()
# Out:
#             PC_0           PC_1          PC_2          PC_3          PC_4  \
# 0  102478.882812 -152156.312500 -10559.550781 -38726.367188 -48718.253906
# 1  -58162.105469  -87774.453125  19177.376953  27506.160156 -26514.996094
# 2 -182412.140625 -155954.218750 -22627.677734  -7519.790527  -1507.230591
# 3 -248007.203125   86975.453125 -18582.691406 -33575.664062    991.179688
# 4  239119.265625 -121731.015625 -37848.253906 -54991.699219 -21650.513672
#
#            PC_5          PC_6          PC_7          PC_8          PC_9  ...  \
# 0 -13733.694336  30539.347656 -76738.734375  -8313.724609 -45783.574219  ...
# 1 -64074.328125  22169.675781 -70108.101562 -11250.588867  -2268.757812  ...
# 2  41557.203125  20310.099609 -67534.054688 -12544.358398 -39998.625000  ...
# 3  77546.062500  47810.238281  73085.710938  40519.632812 -44163.402344  ...
# 4 -94186.781250 -40588.175781  78811.984375  -3839.185303 -12096.173828  ...
#
#           PC_41         PC_42         PC_43         PC_44         PC_45  \
# 0 -34349.324219  -9527.491211 -13203.504883  14588.382812  12240.326172
# 1   3739.857422   5828.090820   3543.179688 -31270.707031  12693.983398
# 2 -12758.887695  19335.726562 -55403.066406 -42271.148438  14237.364258
# 3 -27027.138672  -7749.142090    -87.725510   8691.969727  14386.421875
# 4  -4364.996582  20304.169922   8493.037109  -7146.453613   1347.923340
#
#           PC_46         PC_47         PC_48         PC_49      PC_index
# 0  30733.839844  15006.308594 -18715.478516  17890.667969  TCGA-05-4244
# 1   6717.359375   5949.434082 -26598.332031 -19153.964844  TCGA-05-4249
# 2 -32849.566406  13493.764648  35898.003906 -15939.460938  TCGA-05-4250
# 3 -13188.133789 -11364.585938  11703.898438 -24958.476562  TCGA-05-4382
# 4   7465.342773   3135.352051 -16828.890625 -10948.703125  TCGA-05-4384
#
# [5 rows x 51 columns]

# %% [markdown]
# ## Clinical data

# %%
data_patient = pd.read_table('data_clinical_patient.txt', sep='\t')
print(data_patient.iloc[0])
#****
# Out:
# #Identifier to uniquely specify a patient.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       #STRING
# Subtype                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           STRING
# Text field to hold cancer type acronym used by TCGA PanCanAtlas.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  STRING
# Legacy DMP patient identifier (DMPnnnn)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           STRING
# Age at which a condition or disease was first diagnosed.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          NUMBER
# Sex                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               STRING
# The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria.                                                                                                                                                                                                                                                                                                                                                                                                                                                                               STRING
# The version or edition of the American Joint Committee on Cancer Cancer Staging Handbooks, a publication by the group formed for the purpose of developing a system of clinical staging for cancer that is acceptable to the American medical profession and is compatible with other accepted classifications.                                                                                                                                                                                                                                                                                                                   STRING
# Time interval from the date of last followup to the date of initial pathologic diagnosis, represented as a calculated number of days..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            NUMBER
# Time interval from a person's date of birth to the date of initial pathologic diagnosis, represented as a calculated number of days.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NUMBER
# Time interval from the last day on which a person is known to be alive to the date of initial pathologic diagnosis, represented as a calculated number of days.                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NUMBER
# The text for reporting information about ethnicity.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               STRING
# Form completion date                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              STRING
# Text term to describe the patient's history of neoadjuvant treatment and the kind of treatment given prior to resection of the tumor.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             STRING
# 10th revision of the International Statistical Classification of Diseases and Related Health Problems.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            STRING
# The third edition of the International Classification of Diseases for Oncology, published in 2000, used principally in tumor and cancer registries for coding the site (topography) and the histology (morphology) of neoplasms._The study of the structure of the cells and their arrangement to constitute tissues and, finally, the association among these to form organs.  In pathology, the microscopic process of identifying normal and abnormal morphologic characteristics in tissues, by employing various cytochemical and immunocytochemical stains._A system of numbered categories for representation of data.     STRING
# The third edition of the International Classification of Diseases for Oncology, published in 2000, used principally in tumor and cancer registries for coding the site (topography) and the histology (morphology) of neoplasms._The description of an anatomical region or of a body part._Named locations of, or within, the body._A system of numbered categories for representation of data.                                                                                                                                                                                                                                  STRING
# Informed consent verified                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         STRING
# Yes/No/Unknown indicator to identify whether a patient has had a new tumor event after initial treatment.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         STRING
# Code to represent the defined absence or presence of distant spread or metastases (M) to locations via vascular channels or lymphatics beyond the regional lymph nodes, using criteria established by the American Joint Committee on Cancer (AJCC).                                                                                                                                                                                                                                                                                                                                                                              STRING
# The codes that represent the stage of cancer based on the nodes present (N stage) according to criteria based on multiple editions of the AJCC's Cancer Staging Manual.                                                                                                                                                                                                                                                                                                                                                                                                                                                           STRING
# Code of pathological T (primary tumor) to define the size or contiguous extension of the primary tumor (T), using staging criteria from the American Joint Committee on Cancer (AJCC).                                                                                                                                                                                                                                                                                                                                                                                                                                            STRING
# Person neoplasm cancer status.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    STRING
# Primary lymph node presentation assessment.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       STRING
# Prior diagnosis.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  STRING
# The text for reporting information about race.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    STRING
# Radiation Therapy.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                STRING
# Weight measured in kilograms.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     NUMBER
# Patient Part of PanCan Pathway Analysis                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           STRING
# Overall patient survival status.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  STRING
# Overall survival in months since initial diagonosis.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              NUMBER
# The time period usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               STRING
# The time period (months) usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      NUMBER
# Disease free status since initial treatment.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      STRING
# Disease free (months) since initial treatment.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    NUMBER
# Progression Free Status                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           STRING
# Progress Free Survival (Months)                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   NUMBER
# Name: 0, dtype: object

# %%
data_patient = data_patient.drop([0,1,2,3], axis = 0)
df_patient = data_patient.reset_index(drop=True)
df_patient.head()
# Out:
#   #Identifier to uniquely specify a patient. Subtype  \
# 0                               TCGA-05-4249    LUAD
# 1                               TCGA-05-4250    LUAD
# 2                               TCGA-05-4382    LUAD
# 3                               TCGA-05-4384    LUAD
# 4                               TCGA-05-4389    LUAD
#
#   Text field to hold cancer type acronym used by TCGA PanCanAtlas.  \
# 0                                               LUAD
# 1                                               LUAD
# 2                                               LUAD
# 3                                               LUAD
# 4                                               LUAD
#
#   Legacy DMP patient identifier (DMPnnnn)  \
# 0    4addf05f-3668-4b3f-a17f-c0227329ca52
# 1    f98ecd8a-b878-4f53-b911-20cd8e17281c
# 2    3434b91a-c05f-460f-a078-7b1bb6e7085d
# 3    9a50e7e4-831d-489f-87d2-979e987561cc
# 4    a3de401d-91fe-49a2-bb07-81c1a06506e6
#
#   Age at which a condition or disease was first diagnosed.     Sex  \
# 0                                                 67          Male
# 1                                                 79        Female
# 2                                                 68          Male
# 3                                                 66          Male
# 4                                                 70          Male
#
#   The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria.  \
# 0                                           STAGE IB
# 1                                         STAGE IIIA
# 2                                           STAGE IB
# 3                                         STAGE IIIA
# 4                                           STAGE IA
#
#   The version or edition of the American Joint Committee on Cancer Cancer Staging Handbooks, a publication by the group formed for the purpose of developing a system of clinical staging for cancer that is acceptable to the American medical profession and is compatible with other accepted classifications.  \
# 0                                                6TH
# 1                                                6TH
# 2                                                6TH
# 3                                                6TH
# 4                                                5TH
#
#   Time interval from the date of last followup to the date of initial pathologic diagnosis, represented as a calculated number of days..  \
# 0                                               1523
# 1                                                NaN
# 2                                                607
# 3                                                426
# 4                                               1369
#
#   Time interval from a person's date of birth to the date of initial pathologic diagnosis, represented as a calculated number of days.  \
# 0                                             -24532
# 1                                             -29068
# 2                                             -24868
# 3                                             -24411
# 4                                             -25660
#
#    ... Weight measured in kilograms. Patient Part of PanCan Pathway Analysis  \
# 0  ...                           NaN                                     Yes
# 1  ...                           NaN                                     Yes
# 2  ...                           NaN                                     Yes
# 3  ...                           NaN                                     Yes
# 4  ...                           NaN                                     Yes
#
#   Overall patient survival status.  \
# 0                         0:LIVING
# 1                       1:DECEASED
# 2                         0:LIVING
# 3                         0:LIVING
# 4                         0:LIVING
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#   The time period usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.  \
# 0                         0:ALIVE OR DEAD TUMOR FREE
# 1                                                NaN
# 2                         0:ALIVE OR DEAD TUMOR FREE
# 3                         0:ALIVE OR DEAD TUMOR FREE
# 4                         0:ALIVE OR DEAD TUMOR FREE
#
#   The time period (months) usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#   Disease free status since initial treatment.  \
# 0                                          NaN
# 1                                          NaN
# 2                        1:Recurred/Progressed
# 3                                          NaN
# 4                                          NaN
#
#   Disease free (months) since initial treatment. Progression Free Status  \
# 0                                            NaN              0:CENSORED
# 1                                            NaN              0:CENSORED
# 2                                    10.98070158           1:PROGRESSION
# 3                                            NaN           1:PROGRESSION
# 4                                            NaN              0:CENSORED
#
#   Progress Free Survival (Months)
# 0                     50.07068416
# 1                     3.978038597
# 2                     10.98070158
# 3                     6.016372423
# 4                     45.00772594
#
# [5 rows x 37 columns]

# %%
df_patient.describe()
# Out:
#        #Identifier to uniquely specify a patient. Subtype  \
# count                                         565     501
# unique                                        565       1
# top                                  TCGA-05-4249    LUAD
# freq                                            1     501
#
#        Text field to hold cancer type acronym used by TCGA PanCanAtlas.  \
# count                                                 565
# unique                                                  1
# top                                                  LUAD
# freq                                                  565
#
#        Legacy DMP patient identifier (DMPnnnn)  \
# count                                      513
# unique                                     513
# top       4addf05f-3668-4b3f-a17f-c0227329ca52
# freq                                         1
#
#        Age at which a condition or disease was first diagnosed.     Sex  \
# count                                                 494           513
# unique                                                 52             2
# top                                                    70        Female
# freq                                                   25           275
#
#        The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria.  \
# count                                                 511
# unique                                                  9
# top                                              STAGE IB
# freq                                                  139
#
#        The version or edition of the American Joint Committee on Cancer Cancer Staging Handbooks, a publication by the group formed for the purpose of developing a system of clinical staging for cancer that is acceptable to the American medical profession and is compatible with other accepted classifications.  \
# count                                                 492
# unique                                                  5
# top                                                   7TH
# freq                                                  269
#
#        Time interval from the date of last followup to the date of initial pathologic diagnosis, represented as a calculated number of days..  \
# count                                                 391
# unique                                                331
# top                                                   791
# freq                                                    4
#
#        Time interval from a person's date of birth to the date of initial pathologic diagnosis, represented as a calculated number of days.  \
# count                                                 482
# unique                                                473
# top                                                -30689
# freq                                                    2
#
#         ... Weight measured in kilograms.  \
# count   ...                             0
# unique  ...                             0
# top     ...                           NaN
# freq    ...                           NaN
#
#        Patient Part of PanCan Pathway Analysis  \
# count                                      565
# unique                                       2
# top                                        Yes
# freq                                       501
#
#        Overall patient survival status.  \
# count                               513
# unique                                2
# top                            0:LIVING
# freq                                327
#
#        Overall survival in months since initial diagonosis.  \
# count                                                 504
# unique                                                432
# top                                           26.00519446
# freq                                                    4
#
#        The time period usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.  \
# count                                                 477
# unique                                                  2
# top                            0:ALIVE OR DEAD TUMOR FREE
# freq                                                  363
#
#        The time period (months) usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.  \
# count                                                 504
# unique                                                432
# top                                           26.00519446
# freq                                                    4
#
#        Disease free status since initial treatment.  \
# count                                           304
# unique                                            2
# top                                   0:DiseaseFree
# freq                                            215
#
#        Disease free (months) since initial treatment. Progression Free Status  \
# count                                             301                     513
# unique                                            270                       2
# top                                        16.9313213              0:CENSORED
# freq                                                3                     305
#
#        Progress Free Survival (Months)
# count                              504
# unique                             422
# top                         16.9313213
# freq                                 4
#
# [4 rows x 37 columns]

# %% [markdown]
# ### Merging clinical & cluster data

# %%
df_patient_clusters = pd.merge(left=df_patient, right=clusters_df, left_on='#Identifier to uniquely specify a patient.', right_on="index")
df_patient_clusters.head()
# Out:
#   #Identifier to uniquely specify a patient. Subtype  \
# 0                               TCGA-05-4249    LUAD
# 1                               TCGA-05-4250    LUAD
# 2                               TCGA-05-4382    LUAD
# 3                               TCGA-05-4384    LUAD
# 4                               TCGA-05-4389    LUAD
#
#   Text field to hold cancer type acronym used by TCGA PanCanAtlas.  \
# 0                                               LUAD
# 1                                               LUAD
# 2                                               LUAD
# 3                                               LUAD
# 4                                               LUAD
#
#   Legacy DMP patient identifier (DMPnnnn)  \
# 0    4addf05f-3668-4b3f-a17f-c0227329ca52
# 1    f98ecd8a-b878-4f53-b911-20cd8e17281c
# 2    3434b91a-c05f-460f-a078-7b1bb6e7085d
# 3    9a50e7e4-831d-489f-87d2-979e987561cc
# 4    a3de401d-91fe-49a2-bb07-81c1a06506e6
#
#   Age at which a condition or disease was first diagnosed.     Sex  \
# 0                                                 67          Male
# 1                                                 79        Female
# 2                                                 68          Male
# 3                                                 66          Male
# 4                                                 70          Male
#
#   The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria.  \
# 0                                           STAGE IB
# 1                                         STAGE IIIA
# 2                                           STAGE IB
# 3                                         STAGE IIIA
# 4                                           STAGE IA
#
#   The version or edition of the American Joint Committee on Cancer Cancer Staging Handbooks, a publication by the group formed for the purpose of developing a system of clinical staging for cancer that is acceptable to the American medical profession and is compatible with other accepted classifications.  \
# 0                                                6TH
# 1                                                6TH
# 2                                                6TH
# 3                                                6TH
# 4                                                5TH
#
#   Time interval from the date of last followup to the date of initial pathologic diagnosis, represented as a calculated number of days..  \
# 0                                               1523
# 1                                                NaN
# 2                                                607
# 3                                                426
# 4                                               1369
#
#   Time interval from a person's date of birth to the date of initial pathologic diagnosis, represented as a calculated number of days.  \
# 0                                             -24532
# 1                                             -29068
# 2                                             -24868
# 3                                             -24411
# 4                                             -25660
#
#    ... Overall patient survival status.  \
# 0  ...                         0:LIVING
# 1  ...                       1:DECEASED
# 2  ...                         0:LIVING
# 3  ...                         0:LIVING
# 4  ...                         0:LIVING
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#   The time period usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.  \
# 0                         0:ALIVE OR DEAD TUMOR FREE
# 1                                                NaN
# 2                         0:ALIVE OR DEAD TUMOR FREE
# 3                         0:ALIVE OR DEAD TUMOR FREE
# 4                         0:ALIVE OR DEAD TUMOR FREE
#
#   The time period (months) usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#   Disease free status since initial treatment.  \
# 0                                          NaN
# 1                                          NaN
# 2                        1:Recurred/Progressed
# 3                                          NaN
# 4                                          NaN
#
#   Disease free (months) since initial treatment. Progression Free Status  \
# 0                                            NaN              0:CENSORED
# 1                                            NaN              0:CENSORED
# 2                                    10.98070158           1:PROGRESSION
# 3                                            NaN           1:PROGRESSION
# 4                                            NaN              0:CENSORED
#
#   Progress Free Survival (Months)         index leiden
# 0                     50.07068416  TCGA-05-4249      0
# 1                     3.978038597  TCGA-05-4250      0
# 2                     10.98070158  TCGA-05-4382      1
# 3                     6.016372423  TCGA-05-4384      2
# 4                     45.00772594  TCGA-05-4389      0
#
# [5 rows x 39 columns]

# %%
df_patient_clusters.columns
# Out:
# Index(['#Identifier to uniquely specify a patient.', 'Subtype',
#        'Text field to hold cancer type acronym used by TCGA PanCanAtlas.',
#        'Legacy DMP patient identifier (DMPnnnn)',
#        'Age at which a condition or disease was first diagnosed.', 'Sex',
#        'The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria.',
#        'The version or edition of the American Joint Committee on Cancer Cancer Staging Handbooks, a publication by the group formed for the purpose of developing a system of clinical staging for cancer that is acceptable to the American medical profession and is compatible with other accepted classifications.',
#        'Time interval from the date of last followup to the date of initial pathologic diagnosis, represented as a calculated number of days..',
#        'Time interval from a person's date of birth to the date of initial pathologic diagnosis, represented as a calculated number of days.',
#        'Time interval from the last day on which a person is known to be alive to the date of initial pathologic diagnosis, represented as a calculated number of days.',
#        'The text for reporting information about ethnicity.',
#        'Form completion date',
#        'Text term to describe the patient's history of neoadjuvant treatment and the kind of treatment given prior to resection of the tumor.',
#        '10th revision of the International Statistical Classification of Diseases and Related Health Problems.',
#        'The third edition of the International Classification of Diseases for Oncology, published in 2000, used principally in tumor and cancer registries for coding the site (topography) and the histology (morphology) of neoplasms._The study of the structure of the cells and their arrangement to constitute tissues and, finally, the association among these to form organs.  In pathology, the microscopic process of identifying normal and abnormal morphologic characteristics in tissues, by employing various cytochemical and immunocytochemical stains._A system of numbered categories for representation of data.',
#        'The third edition of the International Classification of Diseases for Oncology, published in 2000, used principally in tumor and cancer registries for coding the site (topography) and the histology (morphology) of neoplasms._The description of an anatomical region or of a body part._Named locations of, or within, the body._A system of numbered categories for representation of data.',
#        'Informed consent verified',
#        'Yes/No/Unknown indicator to identify whether a patient has had a new tumor event after initial treatment.',
#        'Code to represent the defined absence or presence of distant spread or metastases (M) to locations via vascular channels or lymphatics beyond the regional lymph nodes, using criteria established by the American Joint Committee on Cancer (AJCC).',
#        'The codes that represent the stage of cancer based on the nodes present (N stage) according to criteria based on multiple editions of the AJCC's Cancer Staging Manual.',
#        'Code of pathological T (primary tumor) to define the size or contiguous extension of the primary tumor (T), using staging criteria from the American Joint Committee on Cancer (AJCC).',
#        'Person neoplasm cancer status.',
#        'Primary lymph node presentation assessment.', 'Prior diagnosis.',
#        'The text for reporting information about race.', 'Radiation Therapy.',
#        'Weight measured in kilograms.',
#        'Patient Part of PanCan Pathway Analysis',
#        'Overall patient survival status.',
#        'Overall survival in months since initial diagonosis.',
#        'The time period usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.',
#        'The time period (months) usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.',
#        'Disease free status since initial treatment.',
#        'Disease free (months) since initial treatment.',
#        'Progression Free Status', 'Progress Free Survival (Months)', 'index',
#        'leiden'],
#       dtype='object')

# %% [markdown]
# ### Dropping cols not needed

# %%
droper = ['Subtype','Text field to hold cancer type acronym used by TCGA PanCanAtlas.',
       'Legacy DMP patient identifier (DMPnnnn)',
       'The extent of a cancer, especially whether the disease has spread from the original site to other parts of the body based on AJCC staging criteria.',
       'The version or edition of the American Joint Committee on Cancer Cancer Staging Handbooks, a publication by the group formed for the purpose of developing a system of clinical staging for cancer that is acceptable to the American medical profession and is compatible with other accepted classifications.',
       'Time interval from the date of last followup to the date of initial pathologic diagnosis, represented as a calculated number of days..',
       "Time interval from a person's date of birth to the date of initial pathologic diagnosis, represented as a calculated number of days.",
       'Time interval from the last day on which a person is known to be alive to the date of initial pathologic diagnosis, represented as a calculated number of days.',
       'Form completion date',
       "Text term to describe the patient's history of neoadjuvant treatment and the kind of treatment given prior to resection of the tumor.",
       '10th revision of the International Statistical Classification of Diseases and Related Health Problems.',
       'The third edition of the International Classification of Diseases for Oncology, published in 2000, used principally in tumor and cancer registries for coding the site (topography) and the histology (morphology) of neoplasms._The study of the structure of the cells and their arrangement to constitute tissues and, finally, the association among these to form organs.  In pathology, the microscopic process of identifying normal and abnormal morphologic characteristics in tissues, by employing various cytochemical and immunocytochemical stains._A system of numbered categories for representation of data.',
       'The third edition of the International Classification of Diseases for Oncology, published in 2000, used principally in tumor and cancer registries for coding the site (topography) and the histology (morphology) of neoplasms._The description of an anatomical region or of a body part._Named locations of, or within, the body._A system of numbered categories for representation of data.',
       'Informed consent verified',
       'Yes/No/Unknown indicator to identify whether a patient has had a new tumor event after initial treatment.',
       'Code to represent the defined absence or presence of distant spread or metastases (M) to locations via vascular channels or lymphatics beyond the regional lymph nodes, using criteria established by the American Joint Committee on Cancer (AJCC).',
       "The codes that represent the stage of cancer based on the nodes present (N stage) according to criteria based on multiple editions of the AJCC's Cancer Staging Manual.",
       'Code of pathological T (primary tumor) to define the size or contiguous extension of the primary tumor (T), using staging criteria from the American Joint Committee on Cancer (AJCC).',
       'Primary lymph node presentation assessment.', 'Prior diagnosis.',
       'The time period usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.',
       'The time period (months) usually begins at the time of diagnosis or at the start of treatment and ends at the time of death.',
       'Disease free status since initial treatment.','The text for reporting information about ethnicity.',
       'Disease free (months) since initial treatment.','index','The text for reporting information about race.',
         'Weight measured in kilograms.']

# %%
df_patient_clusters = df_patient_clusters.drop(droper, axis=1).reset_index(drop=True)
df_patient_clusters.head()
# Out:
#   #Identifier to uniquely specify a patient.  \
# 0                               TCGA-05-4249
# 1                               TCGA-05-4250
# 2                               TCGA-05-4382
# 3                               TCGA-05-4384
# 4                               TCGA-05-4389
#
#   Age at which a condition or disease was first diagnosed.     Sex  \
# 0                                                 67          Male
# 1                                                 79        Female
# 2                                                 68          Male
# 3                                                 66          Male
# 4                                                 70          Male
#
#   Person neoplasm cancer status. Radiation Therapy.  \
# 0                     Tumor Free                 No
# 1                            NaN                NaN
# 2                     Tumor Free                Yes
# 3                            NaN                Yes
# 4                     Tumor Free                 No
#
#   Patient Part of PanCan Pathway Analysis Overall patient survival status.  \
# 0                                     Yes                         0:LIVING
# 1                                     Yes                       1:DECEASED
# 2                                     Yes                         0:LIVING
# 3                                     Yes                         0:LIVING
# 4                                     Yes                         0:LIVING
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#   Progression Free Status Progress Free Survival (Months) leiden
# 0              0:CENSORED                     50.07068416      0
# 1              0:CENSORED                     3.978038597      0
# 2           1:PROGRESSION                     10.98070158      1
# 3           1:PROGRESSION                     6.016372423      2
# 4              0:CENSORED                     45.00772594      0

# %% [markdown]
# *** Imputation for clinical data - is it dist'b evenly across cols or is there one? (neoplasm NaN - has tumor; radiation for NaN no for tumor free, Nan yes for has tumor)

# %% [markdown]
# ### Merging genes to clinical

# %%
#df_clean = df_clean.add_suffix('_gene')
#df_clean['ID'] = df_clean.index
#df_clean['ID'] = df_clean['ID'].str[:-3]

# %%
binary_columns = ['Overall patient survival status.', 'Progression Free Status']
for col in binary_columns:
    df_patient_clusters[col] = pd.to_numeric(df_patient_clusters[col].str[0])

# %%
df_patient_clusters['Radiation Therapy.'].unique()
# Out:
# array(['No', nan, 'Yes'], dtype=object)

# %%
interpret = True

# %%
if interpret == True:   
    df_patient_clusters['Person neoplasm cancer status.'] = df_patient_clusters['Person neoplasm cancer status.'].map({'With Tumor': 1, 'Tumor Free': 0})
    df_patient_clusters['Radiation Therapy.'] = df_patient_clusters['Radiation Therapy.'].map({'Yes': 1, 'No': 0})
    df_patient_clusters['Patient Part of PanCan Pathway Analysis'] = df_patient_clusters['Patient Part of PanCan Pathway Analysis'].map({'Yes': 1, 'No': 0})
    df_patient_clusters['Sex'] = df_patient_clusters['Sex'].map({'Male': 1, 'Female': 0})

# %%
df_patient_clusters.head()
# Out:
#   #Identifier to uniquely specify a patient.  \
# 0                               TCGA-05-4249
# 1                               TCGA-05-4250
# 2                               TCGA-05-4382
# 3                               TCGA-05-4384
# 4                               TCGA-05-4389
#
#   Age at which a condition or disease was first diagnosed.  Sex  \
# 0                                                 67          1
# 1                                                 79          0
# 2                                                 68          1
# 3                                                 66          1
# 4                                                 70          1
#
#    Person neoplasm cancer status.  Radiation Therapy.  \
# 0                             0.0                 0.0
# 1                             NaN                 NaN
# 2                             0.0                 1.0
# 3                             NaN                 1.0
# 4                             0.0                 0.0
#
#    Patient Part of PanCan Pathway Analysis  Overall patient survival status.  \
# 0                                        1                                 0
# 1                                        1                                 1
# 2                                        1                                 0
# 3                                        1                                 0
# 4                                        1                                 0
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#    Progression Free Status Progress Free Survival (Months) leiden
# 0                        0                     50.07068416      0
# 1                        0                     3.978038597      0
# 2                        1                     10.98070158      1
# 3                        1                     6.016372423      2
# 4                        0                     45.00772594      0

# %%
df_patient_clusters_1= df_patient_clusters.loc[:, ~df_patient_clusters.columns.duplicated()].dropna(axis=0)

# %%
df_patient_clusters_1.head()
# Out:
#   #Identifier to uniquely specify a patient.  \
# 0                               TCGA-05-4249
# 2                               TCGA-05-4382
# 4                               TCGA-05-4389
# 5                               TCGA-05-4390
# 9                               TCGA-05-4398
#
#   Age at which a condition or disease was first diagnosed.  Sex  \
# 0                                                 67          1
# 2                                                 68          1
# 4                                                 70          1
# 5                                                 58          0
# 9                                                 47          0
#
#    Person neoplasm cancer status.  Radiation Therapy.  \
# 0                             0.0                 0.0
# 2                             0.0                 1.0
# 4                             0.0                 0.0
# 5                             0.0                 0.0
# 9                             0.0                 0.0
#
#    Patient Part of PanCan Pathway Analysis  Overall patient survival status.  \
# 0                                        1                                 0
# 2                                        1                                 0
# 4                                        1                                 0
# 5                                        1                                 0
# 9                                        1                                 0
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 2                                        19.95594569
# 4                                        45.00772594
# 5                                         37.0187724
# 9                                        47.04605977
#
#    Progression Free Status Progress Free Survival (Months) leiden
# 0                        0                     50.07068416      0
# 2                        1                     10.98070158      1
# 4                        0                     45.00772594      0
# 5                        1                     12.98615906      2
# 9                        0                     47.04605977      0

# %%
df_genes = df_clean.add_prefix('gene_')
df_genes['ID'] = df_genes.index.str[:-3]
df_genes = df_genes.reset_index(drop=True)

# %%
df_survival = pd.merge(df_patient_clusters, df_genes, left_on='#Identifier to uniquely specify a patient.', right_on='ID').drop('ID', axis=1)
df_survival.head()
# Out:
#   #Identifier to uniquely specify a patient.  \
# 0                               TCGA-05-4249
# 1                               TCGA-05-4250
# 2                               TCGA-05-4382
# 3                               TCGA-05-4384
# 4                               TCGA-05-4389
#
#   Age at which a condition or disease was first diagnosed.  Sex  \
# 0                                                 67          1
# 1                                                 79          0
# 2                                                 68          1
# 3                                                 66          1
# 4                                                 70          1
#
#    Person neoplasm cancer status.  Radiation Therapy.  \
# 0                             0.0                 0.0
# 1                             NaN                 NaN
# 2                             0.0                 1.0
# 3                             NaN                 1.0
# 4                             0.0                 0.0
#
#    Patient Part of PanCan Pathway Analysis  Overall patient survival status.  \
# 0                                        1                                 0
# 1                                        1                                 1
# 2                                        1                                 0
# 3                                        1                                 0
# 4                                        1                                 0
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 1                                        3.978038597
# 2                                        19.95594569
# 3                                        14.00532597
# 4                                        45.00772594
#
#    Progression Free Status Progress Free Survival (Months)  ... gene_55055  \
# 0                        0                     50.07068416  ...    198.589
# 1                        0                     3.978038597  ...    520.899
# 2                        1                     10.98070158  ...    429.630
# 3                        1                     6.016372423  ...    258.302
# 4                        0                     45.00772594  ...    413.262
#
#    gene_11130  gene_7789  gene_158586  gene_79364  gene_440590  gene_79699  \
# 0     287.507    62.1376      493.560    1179.330      20.2833     787.506
# 1    1046.840    60.0182      365.415     843.903      26.5274     475.172
# 2     753.090    40.4424      346.752     946.687      64.8514     908.159
# 3     153.940    80.0244      563.225    1320.710       7.9414     778.864
# 4     889.262    79.5302      625.503    1011.410      71.8121     534.899
#
#    gene_7791  gene_23140  gene_26009
# 0    2351.25    1138.120     690.275
# 1    5437.45    1170.520     532.869
# 2    6770.15    1169.240     663.830
# 3    3341.48    1737.320     723.274
# 4    2565.44     679.195     753.020
#
# [5 rows x 20202 columns]

# %%
df_survival= df_survival.loc[:, ~df_survival.columns.duplicated()].drop('#Identifier to uniquely specify a patient.', axis=1).dropna(axis=0)

# %%
df_survival.head()
# Out:
#   Age at which a condition or disease was first diagnosed.  Sex  \
# 0                                                 67          1
# 2                                                 68          1
# 4                                                 70          1
# 5                                                 58          0
# 9                                                 47          0
#
#    Person neoplasm cancer status.  Radiation Therapy.  \
# 0                             0.0                 0.0
# 2                             0.0                 1.0
# 4                             0.0                 0.0
# 5                             0.0                 0.0
# 9                             0.0                 0.0
#
#    Patient Part of PanCan Pathway Analysis  Overall patient survival status.  \
# 0                                        1                                 0
# 2                                        1                                 0
# 4                                        1                                 0
# 5                                        1                                 0
# 9                                        1                                 0
#
#   Overall survival in months since initial diagonosis.  \
# 0                                        50.07068416
# 2                                        19.95594569
# 4                                        45.00772594
# 5                                         37.0187724
# 9                                        47.04605977
#
#    Progression Free Status Progress Free Survival (Months) leiden  ...  \
# 0                        0                     50.07068416      0  ...
# 2                        1                     10.98070158      1  ...
# 4                        0                     45.00772594      0  ...
# 5                        1                     12.98615906      2  ...
# 9                        0                     47.04605977      0  ...
#
#    gene_55055  gene_11130  gene_7789  gene_158586  gene_79364  gene_440590  \
# 0     198.589     287.507    62.1376      493.560    1179.330      20.2833
# 2     429.630     753.090    40.4424      346.752     946.687      64.8514
# 4     413.262     889.262    79.5302      625.503    1011.410      71.8121
# 5     326.361    1444.680    48.5390      713.396     784.927       7.6641
# 9     374.813     640.278    18.2688      230.535     973.032     119.1820
#
#    gene_79699  gene_7791  gene_23140  gene_26009
# 0     787.506    2351.25    1138.120     690.275
# 2     908.159    6770.15    1169.240     663.830
# 4     534.899    2565.44     679.195     753.020
# 5     618.234    5256.27     780.457     491.138
# 9     700.304    6066.77     593.736     640.061
#
# [5 rows x 20176 columns]

# %% [markdown]
# *** check multidem for genes - perhaps choose genes

# %% [markdown]
# ## Survival analysis

# %%
#!pip install shap

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline, make_pipeline

from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
import seaborn as sns
from sklearn.linear_model import LassoCV
import xgboost as xgb
from sksurv.linear_model import CoxPHSurvivalAnalysis, CoxnetSurvivalAnalysis
from sksurv.metrics import concordance_index_censored
from sksurv.ensemble import RandomSurvivalForest
from sksurv.ensemble import ComponentwiseGradientBoostingSurvivalAnalysis
from sksurv.ensemble import GradientBoostingSurvivalAnalysis
from sklearn.inspection import permutation_importance
import shap

# %%
var = ['Overall survival in months since initial diagonosis.']

y = df_survival[var]
y = y.apply(pd.to_numeric)
y = StandardScaler().fit_transform(y)
X = df_survival.drop(var, axis=1).reset_index(drop=True)
X = X.drop(['Progress Free Survival (Months)',
            'Overall patient survival status.', 'Progression Free Status'],
            axis=1).reset_index(drop=True) #covar too high to be predictors
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42)

# %%
if interpret == True:
    categorical_features = ['Sex']
else:
    categorical_features = ['Sex','Person neoplasm cancer status.',
                            'Radiation Therapy.','Patient Part of PanCan Pathway Analysis', 
                            ]

numeric_features = X_train.drop(categorical_features, axis=1)
numeric_features = numeric_features.columns.tolist()
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

if interpret == True:
    preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ]
        )
    preprocess=preprocessor.fit(X_train.drop(categorical_features, axis=1).reset_index(drop=True)) 
else:

    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, numeric_features),
            ('cat', categorical_transformer, categorical_features)
            ]
            )

    #Fit your preprocessor object
    preprocess=preprocessor.fit(X_train)

# %%
X_train = preprocess.transform(X_train)
X_test = preprocess.transform(X_test)

# %%
X_train.shape
# Out:
# (276, 20171)

# %%
#print(X_train)
#print(X_test)

# %% [markdown]
# ## Modeling

# %% [markdown]
# ### XGBoost

# %%
xgbr = xgb.XGBRegressor(n_estimators=10)
xgbr.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=10, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
print('train: ', xgbr.score(X_train, y_train))
print('test: ', xgbr.score(X_test, y_test))
# Out:
# train:  0.9726976955722717
# test:  -0.25316857554693795

# %% [markdown]
# ### Lasso

# %%
lasso = LassoCV(cv=2, random_state=0).fit(X_train, y_train)

# %%
print('train: ', lasso.score(X_train, y_train), '\ntest: ', lasso.score(X_test, y_test))
# Out:
# train:  0.0
# test:  -0.004769983641210063

# %% [markdown]
# ### Cox

# %% [markdown]
# ### still workshopping this *****

# %%
df_y_cox = pd.concat([df_survival['Overall survival in months since initial diagonosis.'].astype(bool), df_survival['Overall survival in months since initial diagonosis.'].apply(pd.to_numeric)], axis=1).to_records(index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [177], in <cell line: 1>()
# ----> 1 df_y_cox = pd.concat([df_survival['Overall survival in months since initial diagonosis.'].astype(bool), df_survival['Overall survival in months since initial diagonosis.'].apply(pd.to_numeric)], axis=1).to_records(index=False)
#
# File /opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:2438, in DataFrame.to_records(self, index, column_dtypes, index_dtypes)
#    2435         msg = f"Invalid dtype {dtype_mapping} specified for {element} {name}"
#    2436         raise ValueError(msg)
# -> 2438 return np.rec.fromarrays(arrays, dtype={"names": names, "formats": formats})
#
# File /opt/anaconda3/lib/python3.9/site-packages/numpy/core/records.py:653, in fromarrays(arrayList, dtype, shape, formats, names, titles, aligned, byteorder)
#     650     formats = [obj.dtype for obj in arrayList]
#     652 if dtype is not None:
# --> 653     descr = sb.dtype(dtype)
#     654 else:
#     655     descr = format_parser(formats, names, titles, aligned, byteorder).dtype
#
# ValueError: name already used as a name or title

# %%
y = df_y_cox

X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=42)
X_train = preprocess.transform(X_train)
X_test = preprocess.transform(X_test)

# %%
cox_elastic_net = CoxnetSurvivalAnalysis()
params = {'l1_ratio':np.arange(0.4,1.,0.05), "alpha_min_ratio":np.arange(0.1,0.7,0.05)}
cox_net_cv = GridSearchCV(cox_elastic_net,
                        param_grid=params,
                        n_jobs=-1,
                        cv=10
                        )

cox_net = CoxnetSurvivalAnalysis(l1_ratio= 0.9, alpha_min_ratio= 0.25)

# %%
cox_net.fit(X_train, y_train)

# %%
rsf = RandomSurvivalForest(n_estimators=10,
                           min_samples_split=10,
                           min_samples_leaf=10,
                           n_jobs=-1,
                           random_state=42)
rsf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [178], in <cell line: 6>()
#       1 rsf = RandomSurvivalForest(n_estimators=10,
#       2                            min_samples_split=10,
#       3                            min_samples_leaf=10,
#       4                            n_jobs=-1,
#       5                            random_state=42)
# ----> 6 rsf.fit(X_train, y_train)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sksurv/ensemble/forest.py:90, in _BaseSurvivalForest.fit(self, X, y, sample_weight)
#      87 self._validate_params()
#      89 X = self._validate_data(X, dtype=DTYPE, accept_sparse="csc", ensure_min_samples=2)
# ---> 90 event, time = check_array_survival(X, y)
#      92 self.n_features_in_ = X.shape[1]
#      93 time = time.astype(np.float64)
#
# File /opt/anaconda3/lib/python3.9/site-packages/sksurv/util.py:189, in check_array_survival(X, y)
#     165 def check_array_survival(X, y):
#     166     """Check that all arrays have consistent first dimensions.
#     167
#     168     Parameters
#    (...)
#     187         Time of event or censoring.
#     188     """
# --> 189     event, time = check_y_survival(y)
#     190     check_consistent_length(X, event, time)
#     191     return event, time
#
# File /opt/anaconda3/lib/python3.9/site-packages/sksurv/util.py:132, in check_y_survival(y_or_event, allow_all_censored, *args)
#     129 y = y_or_event
#     131 if not isinstance(y, np.ndarray) or y.dtype.fields is None or len(y.dtype.fields) != 2:
# --> 132     raise ValueError('y must be a structured array with the first field'
#     133                      ' being a binary class event indicator and the second field'
#     134                      ' the time of the event/censoring')
#     136 event_field, time_field = y.dtype.names
#     137 y_event = y[event_field]
#
# ValueError: y must be a structured array with the first field being a binary class event indicator and the second field the time of the event/censoring

# %% [markdown]
# ## rec - maybe 2 rounds of cross val for cox
